# %% [markdown]
# <div style="background:#5D4037; padding:20px; border-radius:10px;">
# <h1 style="text-align:center; color:white; margin:0; font-family:'Garamond';">
# Proyecto de Café Premium
# </h1>
# </div>

# %% [markdown]
#     Somos el equipo de datos de una marca de café de especialidad que quiere romper el mercado. No aspiramos a ser “otro café más”: nuestro objetivo es convertirnos en la referencia absoluta para personas exigentes que ya no soportan el café plano y repetitivo de las cadenas masivas.
# Nuestra misión es clara: convertirnos en el distribuidor número uno para amantes del café premium. No se trata solo de vender más, sino de vender mejor: el origen adecuado, el tueste perfecto y al cliente correcto.
# Nuestra propuesta de valor se basa en tres pilares fundamentales:
# - seleccionar los mejores orígenes,
# - aplicar el tostado más adecuado para cada café,
# - ofrecer una calidad alta y consistente.
# El reto es que los datos nos llegan en bruto y con bastante caos. Si construimos un modelo deficiente, tomaremos decisiones equivocadas y perderemos ventaja frente a la competencia. Por eso nuestro trabajo consiste en transformar esos datos, darles sentido y convertirlos en una herramienta estratégica que nos permita diferenciarnos de verdad.

# %% [markdown]
# ## 🚀 Objetivo 1: pasar de una tabla desordenada (`ventas_cafe_raw`) a un modelo relacional en 3FN sin perder informacion.

# %%
import sqlite3
import pandas as pd

# Ajusta la ruta si tu ventas-cafe-raw.db está en otra carpeta
con = sqlite3.connect("tostador-cafe-raw2.db")

# ¿Qué tablas hay disponibles?
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", con)
# Out:
#               name
# 0  ventas_cafe_raw

# %% [markdown]
# ### 🔎 1. Visualizamos la base de datos inicial y desordenada.
#
# Antes de hacer ningún cambio vamos a realizar unas métricas iniciales para posteriormente verificar que no cometemos errores al realizar el proceso de normalizacion:
#
# ---
#
# En primer lugar hacemos una consulta para ver el número de filas que tiene la tabla de datos inicial:

# %%
pd.read_sql("SELECT COUNT(*) AS filas_raw FROM 'ventas_cafe_raw'", con)
# Out:
#    filas_raw
# 0        119

# %% [markdown]
# Hacemos una segunda consulta en la que unicamente queremos ver cúantas operaciones de venta hay:

# %%
pd.read_sql("""
SELECT COUNT(DISTINCT id_venta) AS ventas_unicas_raw FROM ventas_cafe_raw;
""",con)
# Out:
#    ventas_unicas_raw
# 0                 98

# %% [markdown]
# Y una tercera consulta para ver cual es el importe total de ventas:

# %%
pd.read_sql("""
SELECT ROUND(SUM(total_venta), 2) AS facturacion_raw FROM ventas_cafe_raw;
""",con)
# Out:
#    facturacion_raw
# 0          3371.48

# %%
from IPython.display import HTML

HTML("""
<style>

/* --- Efecto hover premium con animación --- */
.premium-table td {
    transition: background-color 0.25s ease, color 0.25s ease;
}

.premium-table td:hover {
    background-color: #C8923A !important;
    color: #1A0800 !important;
    cursor: pointer;
}

</style>
""")
# Out:
# <style>
#
# /* --- Efecto hover premium con animación --- */
# .premium-table td {
#     transition: background-color 0.25s ease, color 0.25s ease;
# }
#
# .premium-table td:hover {
#     background-color: #C8923A !important;
#     color: #1A0800 !important;
#     cursor: pointer;
# }
#
# </style>

# %%
# Antes de empezar, importamos las librerias que vamos a utilizar:

import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === Tema de estilo Café Premium para DataFrames ===

premium_styles = [
    {"selector": "th",
     "props": "background-color: #C8923A; color: #1A0800; font-weight: bold; padding: 8px;"},
    
    {"selector": "td",
     "props": "background-color: #2A1205; color: #F2E0C8; padding: 6px;"},
    
    {"selector": "table",
     "props": "border: 1px solid #C8923A; border-collapse: collapse;"}
]

premium_props = {
    "border": "1px solid #C8923A",
    "padding": "6px"
}

# === Zebra premium (filas alternas) ===
def premium_zebra(row):
    if row.name % 2 == 0:
        return ['background-color: #2A1205; color:#F2E0C8'] * len(row)
    else:
        return ['background-color: #1E0D02; color:#F2E0C8'] * len(row)

# === Función para estilizar cualquier DataFrame ===
def estilizar(df, zebra=False):
    styled = (
        df.style
        .set_table_styles(premium_styles)
        .set_properties(**premium_props)
        .set_table_attributes('class="premium-table"')  # Clase para el hover
    )
    if zebra:
        styled = styled.apply(premium_zebra, axis=1)
    return styled

conn = sqlite3.connect("tostador-cafe-raw.db")

# %% [markdown]
# <h2><strong>El ejercicio plantea una serie de cuestiones y las divide en varios apartados que resolveremos a continuación:</strong></h2>

# %% [markdown]
# <div style="
#     background:#2A1205;
#     border:1px solid #C8923A;
#     border-radius:10px;
#     padding:20px;
#     color:#F2E0C8;
#     font-family:'Lato', sans-serif;
#     line-height:1.7;
# ">
#
#   <h2 style="color:#E8B86D; font-family:'Playfair Display', serif; margin-bottom:10px;">
#     Parte A – Diagnóstico
#   </h2>
#
#   <h3 style="color:#C8923A; margin-top:18px;">1. Seis problemas de diseño o calidad de dato</h3>
#   <ul>
#     <li><strong>Redundancia de datos:</strong> <code>email_cliente</code> y <code>nombre_cliente</code> se repiten en cada fila de venta.</li>
#     <li><strong>Mezcla de entidades:</strong> la tabla contiene datos del cliente, del producto, de la zona y de la venta en un solo lugar.</li>
#     <li><strong>Formato inconsistente:</strong> la columna <code>formato_paquete</code> mezcla unidades (kg, gr) y cantidades.</li>
#     <li><strong>Datos subjetivos:</strong> las columnas <code>valoración</code> y <code>comentario_valoración</code> dependen de criterios personales.</li>
#     <li><strong>Inconsistencias en el precio del café:</strong> no queda claro si son errores o promociones.</li>
#     <li><strong>Valoraciones duplicadas:</strong> la valoración depende del canal (online/tienda), pero lo que se valora es el café.</li>
#   </ul>
#
#   <h3 style="color:#C8923A; margin-top:18px;">2. Una anomalía de inserción</h3>
#   <p>No se puede dar de alta un café, zona o cliente sin registrar antes una venta, ya que todo depende de <code>id_venta</code>.</p>
#
#   <h3 style="color:#C8923A; margin-top:18px;">3. Una anomalía de actualización</h3>
#   <p>Actualizar un email obliga a modificarlo en todas las filas donde aparece, con riesgo de inconsistencias.</p>
#
#   <h3 style="color:#C8923A; margin-top:18px;">4. Una anomalía de borrado</h3>
#   <p>Si se borra la única venta de Pola de Lena, desaparece también la zona de la base de datos.</p>
#
# </div>

# %% [markdown]
# <div style="
#     background:#2A1205;
#     border:1px solid #C8923A;
#     border-radius:10px;
#     padding:20px;
#     color:#F2E0C8;
#     font-family:'Lato', sans-serif;
#     line-height:1.7;
# ">
#
#   <h2 style="color:#E8B86D; font-family:'Playfair Display', serif; margin-bottom:10px;">
#     Parte B – Normalización
#   </h2>
#
#   <h3 style="color:#C8923A; margin-top:18px;">1. Propuesta de tablas finales (PK y FK claras)</h3>
#
#   <div style="text-align:center; margin: 1.5rem 0;">
#     <img src="Imagen Alain.png" alt="Diagrama de tablas finales"
#          style="max-width:100%; border:1px solid #C8923A; border-radius:8px;">
#   </div>
#
#   <h3 style="color:#C8923A; margin-top:18px;">2. Paso por 1FN, 2FN y 3FN</h3>
#
#   <p>
#     Se aplicó el proceso de normalización para eliminar redundancias, dependencias parciales y dependencias transitivas.
#     El resultado es un modelo relacional más limpio, eficiente y preparado para análisis posteriores.
#   </p>
#
#   <div style="text-align:center; margin: 1.5rem 0;">
#     <img src="Imagen Fran.png" alt="Diagrama de normalización"
#          style="max-width:100%; border:1px solid #C8923A; border-radius:8px;">
#   </div>
#
#   <h3 style="color:#C8923A; margin-top:18px;">Ejemplo de creación de tablas</h3>
#
#   <div style="
#       background:#1E0D02;
#       border:1px solid #C8923A;
#       border-radius:8px;
#       padding:1rem 1.4rem;
#       margin-top:1rem;
#       font-family:'Playfair Display', serif;
#       color:#F2E0C8;
#       font-size:0.9rem;
#   ">
# <pre style="white-space:pre-wrap; color:#F2E0C8;">
# CREATE TABLE "cafe" (
#   "id_cafe" INTEGER NOT NULL,
#   "nombre_cafe" TEXT NOT NULL,
#   "origen_cafe" TEXT NOT NULL,
#   "proceso_cafe" TEXT NOT NULL,
#   "nivel_tueste" TEXT NOT NULL,
#   PRIMARY KEY("id_cafe")
# );
# </pre>
#   </div>
#
#   <h3 style="color:#C8923A; margin-top:18px;">Ejemplo de inserción de datos</h3>
#
#   <div style="
#       background:#1E0D02;
#       border:1px solid #C8923A;
#       border-radius:8px;
#       padding:1rem 1.4rem;
#       margin-top:1rem;
#       font-family:'Playfair Display', serif;
#       color:#F2E0C8;
#       font-size:0.9rem;
#   ">
# <pre style="white-space:pre-wrap; color:#F2E0C8;">
# INSERT INTO cafe (id_cafe, nombre_cafe, origen_cafe, proceso_cafe, nivel_tueste)
# SELECT DISTINCT id_cafe, nombre_cafe, origen_cafe, proceso_cafe, nivel_tueste
# FROM ventas_cafe_raw;
# </pre>
#   </div>
#
#   <h3 style="color:#C8923A; margin-top:18px;">Consulta de la tabla resultante</h3>
#
#   <div style="
#       background:#1E0D02;
#       border:1px solid #C8923A;
#       border-radius:8px;
#       padding:1rem 1.4rem;
#       margin-top:1rem;
#       font-family:'Playfair Display', serif;
#       color:#F2E0C8;
#       font-size:0.9rem;
#   ">
# <pre style="white-space:pre-wrap; color:#F2E0C8;">
# conn = sqlite3.connect("tostador-cafe-raw.db")
# pd.read_sql("SELECT * FROM cafe;", conn)
# </pre>
#   </div>
#
#   <h3 style="color:#C8923A; margin-top:18px;">Resultado de la tabla <code>cafe</code></h3>
#
#   <table style="
#       width:100%;
#       border-collapse: collapse;
#       margin-top:1rem;
#       font-size:0.9rem;
#       color: #F2E0C8;
#       background: #2A1205;
#       border:1px solid #C8923A;
#       border-radius:8px;
#       overflow:hidden;
#   ">
#     <thead>
#       <tr style="background:#C8923A; color:#1A0800;">
#         <th style="padding:8px;">id_cafe</th>
#         <th style="padding:8px;">nombre_cafe</th>
#         <th style="padding:8px;">origen_cafe</th>
#         <th style="padding:8px;">proceso_cafe</th>
#         <th style="padding:8px;">nivel_tueste</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr><td style="padding:6px;">1</td><td>Colombia Huila</td><td>Colombia</td><td>Lavado</td><td>Medio</td></tr>
#       <tr><td style="padding:6px;">2</td><td>Etiopia Yirgacheffe</td><td>Etiopia</td><td>Lavado</td><td>Claro</td></tr>
#       <tr><td style="padding:6px;">3</td><td>Brasil Cerrado</td><td>Brasil</td><td>Natural</td><td>Medio</td></tr>
#       <tr><td style="padding:6px;">4</td><td>Guatemala Antigua</td><td>Guatemala</td><td>Honey</td><td>Medio-Oscuro</td></tr>
#       <tr><td style="padding:6px;">5</td><td>Peru Cajamarca</td><td>Peru</td><td>Lavado</td><td>Claro</td></tr>
#       <tr><td style="padding:6px;">6</td><td>Kenia Nyeri</td><td>Kenia</td><td>Lavado</td><td>Claro</td></tr>
#     </tbody>
#   </table>
#
# </div>

# %% [markdown]
# <div style="
#     background:#2A1205;
#     border:1px solid #C8923A;
#     border-radius:10px;
#     padding:20px;
#     color:#F2E0C8;
#     font-family:'Lato', sans-serif;
#     line-height:1.7;
# ">
#
#   <h3 style="color:#C8923A; margin-top:10px;">
#     Protocolo anti-pérdida de datos
#   </h3>
#
#   <p>
#     Una vez pobladas nuestras tablas, comprobamos si las métricas iniciales coinciden con las de la base de datos normalizada.
#   </p>
#
#   <h4 style="color:#E8B86D; font-family:'Playfair Display', serif; margin-top:15px;">
#     1ª métrica: Número de filas
#   </h4>
#
#   <p>El número de filas original era <strong>119</strong>.</p>
#
# </div>

# %%
filas = pd.read_sql("SELECT COUNT(*) AS filas_normalizado FROM detalle_venta;", conn)

estilizar(filas)
# Out:
# <style type="text/css">
# #T_533a6 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_533a6 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_533a6 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_533a6_row0_col0 {
#   border: 1px solid #C8923A;
#   padding: 6px;
# }
# </style>
# <table id="T_533a6" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_533a6_level0_col0" class="col_heading level0 col0" >filas_normalizado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_533a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_533a6_row0_col0" class="data row0 col0" >119</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="
#     background:#2A1205;
#     border:1px solid #C8923A;
#     border-radius:10px;
#     padding:20px;
#     color:#F2E0C8;
#     font-family:'Lato', sans-serif;
#     line-height:1.7;
# ">
#
#   <h4 style="color:#E8B86D; font-family:'Playfair Display', serif; margin-top:15px;">
#     2ª métrica: Número de ventas unicas
#   </h4>
#
#   <p>Antes teniamos <strong>98</strong> ventas únicas.</p>
#
# </div>

# %%
ventas_unicas = pd.read_sql("SELECT COUNT(DISTINCT id_venta) AS ventas_unicas_normalizadas FROM venta;", conn)

estilizar(ventas_unicas)
# Out:
# <style type="text/css">
# #T_63d9e th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_63d9e td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_63d9e table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_63d9e_row0_col0 {
#   border: 1px solid #C8923A;
#   padding: 6px;
# }
# </style>
# <table id="T_63d9e" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63d9e_level0_col0" class="col_heading level0 col0" >ventas_unicas_normalizadas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63d9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63d9e_row0_col0" class="data row0 col0" >98</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="
#     background:#2A1205;
#     border:1px solid #C8923A;
#     border-radius:10px;
#     padding:20px;
#     color:#F2E0C8;
#     font-family:'Lato', sans-serif;
#     line-height:1.7;
# ">
#
#   <h4 style="color:#E8B86D; font-family:'Playfair Display', serif; margin-top:15px;">
#     3ª métrica: Facturación total
#   </h4>
#
#   <p>Nuestro importe final de ventas era de <strong>3371.48</strong>.</p>
#
# </div>

# %%
facturacion = pd.read_sql("SELECT ROUND(SUM(total_venta), 2) AS facturacion_normalizada FROM detalle_venta;", conn)

estilizar(facturacion)
# Out:
# <style type="text/css">
# #T_71ab3 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_71ab3 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_71ab3 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_71ab3_row0_col0 {
#   border: 1px solid #C8923A;
#   padding: 6px;
# }
# </style>
# <table id="T_71ab3" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71ab3_level0_col0" class="col_heading level0 col0" >facturacion_normalizada</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71ab3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71ab3_row0_col0" class="data row0 col0" >3371.480000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="
#     background:#2A1205;
#     border:1px solid #C8923A;
#     border-radius:10px;
#     padding:20px;
#     color:#F2E0C8;
#     font-family:'Lato', sans-serif;
#     line-height:1.7;
#     margin-top:20px;
# ">
#
#   <div style="
#       background:#1E0D02;
#       border:1px solid #C8923A;
#       border-radius:8px;
#       padding:1rem 1.4rem;
#       font-family:'Playfair Display', serif;
#       color:#E8B86D;
#       font-size:1.1rem;
#       text-align:center;
#   ">
#     Hemos conseguido pasar de una tabla con datos sin organizar a una tabla normalizada en la que las métricas coinciden.<br>
#     <strong style="color:#C8923A;">¡Objetivo 1 CONSEGUIDO!</strong>
#   </div>
#
# </div>

# %% [markdown]
# ## 🚀 Objetivo 2: Responder a las preguntas SQL de negocios

# %% [markdown]
# ### Consulta 1: Los 5 cafes con mayor facturacion

# %%
cafes = pd.read_sql("""SELECT c.id_cafe, c.nombre_cafe, SUM(dv.total_venta) AS Total_facturacion
FROM detalle_venta AS dv
INNER JOIN cafe as c
	ON c.id_cafe = dv.id_cafe
GROUP BY nombre_cafe
ORDER BY SUM(dv.total_venta) DESC
LIMIT 5;""", conn)


estilizar(cafes, zebra=True)
# Out:
# <style type="text/css">
# #T_57a47 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_57a47 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_57a47 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_57a47_row0_col0, #T_57a47_row0_col1, #T_57a47_row0_col2, #T_57a47_row2_col0, #T_57a47_row2_col1, #T_57a47_row2_col2, #T_57a47_row4_col0, #T_57a47_row4_col1, #T_57a47_row4_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_57a47_row1_col0, #T_57a47_row1_col1, #T_57a47_row1_col2, #T_57a47_row3_col0, #T_57a47_row3_col1, #T_57a47_row3_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_57a47" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57a47_level0_col0" class="col_heading level0 col0" >id_cafe</th>
#       <th id="T_57a47_level0_col1" class="col_heading level0 col1" >nombre_cafe</th>
#       <th id="T_57a47_level0_col2" class="col_heading level0 col2" >Total_facturacion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57a47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57a47_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_57a47_row0_col1" class="data row0 col1" >Etiopia Yirgacheffe</td>
#       <td id="T_57a47_row0_col2" class="data row0 col2" >896.370000</td>
#     </tr>
#     <tr>
#       <th id="T_57a47_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57a47_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_57a47_row1_col1" class="data row1 col1" >Colombia Huila</td>
#       <td id="T_57a47_row1_col2" class="data row1 col2" >766.960000</td>
#     </tr>
#     <tr>
#       <th id="T_57a47_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57a47_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_57a47_row2_col1" class="data row2 col1" >Guatemala Antigua</td>
#       <td id="T_57a47_row2_col2" class="data row2 col2" >508.800000</td>
#     </tr>
#     <tr>
#       <th id="T_57a47_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57a47_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_57a47_row3_col1" class="data row3 col1" >Kenia Nyeri</td>
#       <td id="T_57a47_row3_col2" class="data row3 col2" >476.830000</td>
#     </tr>
#     <tr>
#       <th id="T_57a47_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_57a47_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_57a47_row4_col1" class="data row4 col1" >Brasil Cerrado</td>
#       <td id="T_57a47_row4_col2" class="data row4 col2" >395.940000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.bar(cafes['nombre_cafe'], cafes['Total_facturacion'])
plt.xticks(rotation=45)
plt.title("Ventas por café")
plt.xlabel("Café")
plt.ylabel("Total vendido")
plt.show()

# %% [markdown]
# ### Consulta 2: Zonas con mayor volumen de ventas

# %% [markdown]
# Opcion 1. Zonas con mayor volumen de ventas (por facturación)

# %%
zona = pd.read_sql("""SELECT z.id_zona, z.nombre_zona AS Ciudad, SUM(dv.total_venta) AS Ventas
FROM zona as z
INNER JOIN cliente as cl
	ON z.id_zona = cl.id_zona
INNER JOIN venta as v
	ON cl.id_cliente = v.id_cliente
INNER JOIN detalle_venta as dv
	ON v.id_venta = dv.id_venta
GROUP BY nombre_zona
ORDER BY SUM(dv.total_venta) DESC;""", conn)

estilizar(zona, zebra=True)
# Out:
# <style type="text/css">
# #T_78c40 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_78c40 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_78c40 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_78c40_row0_col0, #T_78c40_row0_col1, #T_78c40_row0_col2, #T_78c40_row2_col0, #T_78c40_row2_col1, #T_78c40_row2_col2, #T_78c40_row4_col0, #T_78c40_row4_col1, #T_78c40_row4_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_78c40_row1_col0, #T_78c40_row1_col1, #T_78c40_row1_col2, #T_78c40_row3_col0, #T_78c40_row3_col1, #T_78c40_row3_col2, #T_78c40_row5_col0, #T_78c40_row5_col1, #T_78c40_row5_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_78c40" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78c40_level0_col0" class="col_heading level0 col0" >id_zona</th>
#       <th id="T_78c40_level0_col1" class="col_heading level0 col1" >Ciudad</th>
#       <th id="T_78c40_level0_col2" class="col_heading level0 col2" >Ventas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78c40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78c40_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_78c40_row0_col1" class="data row0 col1" >Oviedo</td>
#       <td id="T_78c40_row0_col2" class="data row0 col2" >764.000000</td>
#     </tr>
#     <tr>
#       <th id="T_78c40_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78c40_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_78c40_row1_col1" class="data row1 col1" >Villaviciosa</td>
#       <td id="T_78c40_row1_col2" class="data row1 col2" >722.440000</td>
#     </tr>
#     <tr>
#       <th id="T_78c40_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78c40_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_78c40_row2_col1" class="data row2 col1" >Gijon</td>
#       <td id="T_78c40_row2_col2" class="data row2 col2" >625.350000</td>
#     </tr>
#     <tr>
#       <th id="T_78c40_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78c40_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_78c40_row3_col1" class="data row3 col1" >Aviles</td>
#       <td id="T_78c40_row3_col2" class="data row3 col2" >515.840000</td>
#     </tr>
#     <tr>
#       <th id="T_78c40_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78c40_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_78c40_row4_col1" class="data row4 col1" >Nava</td>
#       <td id="T_78c40_row4_col2" class="data row4 col2" >513.500000</td>
#     </tr>
#     <tr>
#       <th id="T_78c40_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_78c40_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_78c40_row5_col1" class="data row5 col1" >Pola de Lena</td>
#       <td id="T_78c40_row5_col2" class="data row5 col2" >230.350000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.pie(zona['Ventas'], labels=zona['Ciudad'], autopct='%1.1f%%')
plt.title("Distribución de ventas por café")
plt.show()

# %% [markdown]
# Opcion 2: Zonas con mayor volumen de ventas (por unidades vendidas)

# %%
zona2 = pd.read_sql("""SELECT z.id_zona, z.nombre_zona, SUM(dv.cantidad) AS unidades
FROM zona as z
INNER JOIN detalle_venta as dv
	ON z.id_zona = c.id_zona
INNER JOIN cliente as c
	ON c.id_cliente = v.id_cliente
INNER JOIN venta as v
	ON v.id_venta = dv.id_venta
GROUP BY nombre_zona
ORDER BY SUM(dv.cantidad) DESC;""", conn)


estilizar(zona2, zebra=True)
# Out:
# <style type="text/css">
# #T_d3e0d th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_d3e0d td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_d3e0d table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_d3e0d_row0_col0, #T_d3e0d_row0_col1, #T_d3e0d_row0_col2, #T_d3e0d_row2_col0, #T_d3e0d_row2_col1, #T_d3e0d_row2_col2, #T_d3e0d_row4_col0, #T_d3e0d_row4_col1, #T_d3e0d_row4_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_d3e0d_row1_col0, #T_d3e0d_row1_col1, #T_d3e0d_row1_col2, #T_d3e0d_row3_col0, #T_d3e0d_row3_col1, #T_d3e0d_row3_col2, #T_d3e0d_row5_col0, #T_d3e0d_row5_col1, #T_d3e0d_row5_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_d3e0d" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3e0d_level0_col0" class="col_heading level0 col0" >id_zona</th>
#       <th id="T_d3e0d_level0_col1" class="col_heading level0 col1" >nombre_zona</th>
#       <th id="T_d3e0d_level0_col2" class="col_heading level0 col2" >unidades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3e0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3e0d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d3e0d_row0_col1" class="data row0 col1" >Oviedo</td>
#       <td id="T_d3e0d_row0_col2" class="data row0 col2" >58</td>
#     </tr>
#     <tr>
#       <th id="T_d3e0d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3e0d_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_d3e0d_row1_col1" class="data row1 col1" >Villaviciosa</td>
#       <td id="T_d3e0d_row1_col2" class="data row1 col2" >47</td>
#     </tr>
#     <tr>
#       <th id="T_d3e0d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3e0d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d3e0d_row2_col1" class="data row2 col1" >Aviles</td>
#       <td id="T_d3e0d_row2_col2" class="data row2 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_d3e0d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3e0d_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_d3e0d_row3_col1" class="data row3 col1" >Gijon</td>
#       <td id="T_d3e0d_row3_col2" class="data row3 col2" >37</td>
#     </tr>
#     <tr>
#       <th id="T_d3e0d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3e0d_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_d3e0d_row4_col1" class="data row4 col1" >Nava</td>
#       <td id="T_d3e0d_row4_col2" class="data row4 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_d3e0d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d3e0d_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_d3e0d_row5_col1" class="data row5 col1" >Pola de Lena</td>
#       <td id="T_d3e0d_row5_col2" class="data row5 col2" >17</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.bar(zona2['nombre_zona'], zona2['unidades'])
plt.xticks(rotation=45)
plt.title("Ventas por café")
plt.xlabel("Café")
plt.ylabel("Total vendido")
plt.show()

# %% [markdown]
# ### Consulta 3: Top 3 cafes por valoracion media (minimo 3 valoraciones)

# %%
top3 = pd.read_sql("""SELECT c.nombre_cafe,
		ROUND(AVG(val.valoracion), 2) AS valoracion_media,
		COUNT(*) AS numero_valoraciones
FROM valoraciones AS val
JOIN cafe AS c ON val.id_cafe = c.id_cafe
GROUP BY c.nombre_cafe
HAVING COUNT(*) >= 3
ORDER BY valoracion_media DESC
LIMIT 3;""", conn)

estilizar(top3, zebra=True)
# Out:
# <style type="text/css">
# #T_a4b0a th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_a4b0a td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_a4b0a table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_a4b0a_row0_col0, #T_a4b0a_row0_col1, #T_a4b0a_row0_col2, #T_a4b0a_row2_col0, #T_a4b0a_row2_col1, #T_a4b0a_row2_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_a4b0a_row1_col0, #T_a4b0a_row1_col1, #T_a4b0a_row1_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_a4b0a" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4b0a_level0_col0" class="col_heading level0 col0" >nombre_cafe</th>
#       <th id="T_a4b0a_level0_col1" class="col_heading level0 col1" >valoracion_media</th>
#       <th id="T_a4b0a_level0_col2" class="col_heading level0 col2" >numero_valoraciones</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4b0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4b0a_row0_col0" class="data row0 col0" >Etiopia Yirgacheffe</td>
#       <td id="T_a4b0a_row0_col1" class="data row0 col1" >5.000000</td>
#       <td id="T_a4b0a_row0_col2" class="data row0 col2" >35</td>
#     </tr>
#     <tr>
#       <th id="T_a4b0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4b0a_row1_col0" class="data row1 col0" >Colombia Huila</td>
#       <td id="T_a4b0a_row1_col1" class="data row1 col1" >5.000000</td>
#       <td id="T_a4b0a_row1_col2" class="data row1 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_a4b0a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4b0a_row2_col0" class="data row2 col0" >Kenia Nyeri</td>
#       <td id="T_a4b0a_row2_col1" class="data row2 col1" >4.710000</td>
#       <td id="T_a4b0a_row2_col2" class="data row2 col2" >14</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Consulta 4: Ticket medio por canal ('tienda' vs 'online')

# %%
ticketmedio = pd.read_sql("""SELECT v.canal_venta, 
	ROUND(SUM(dv.cantidad * dv.precio_unitario) / COUNT(DISTINCT v.id_venta), 2)
	AS ticket_medio
FROM venta AS v
JOIN detalle_venta AS dv ON v.id_venta = dv.id_venta
GROUP BY v.canal_venta;""", conn)

estilizar(ticketmedio, zebra=True)
# Out:
# <style type="text/css">
# #T_3f0b5 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_3f0b5 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_3f0b5 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_3f0b5_row0_col0, #T_3f0b5_row0_col1 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_3f0b5_row1_col0, #T_3f0b5_row1_col1 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_3f0b5" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f0b5_level0_col0" class="col_heading level0 col0" >canal_venta</th>
#       <th id="T_3f0b5_level0_col1" class="col_heading level0 col1" >ticket_medio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f0b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f0b5_row0_col0" class="data row0 col0" >online</td>
#       <td id="T_3f0b5_row0_col1" class="data row0 col1" >33.690000</td>
#     </tr>
#     <tr>
#       <th id="T_3f0b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f0b5_row1_col0" class="data row1 col0" >tienda</td>
#       <td id="T_3f0b5_row1_col1" class="data row1 col1" >35.120000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Consulta 5: recomendacion de cafe para "snobs"

# %%
snobs = pd.read_sql("""SELECT c.nombre_cafe, dv.formato_paquete,
	ROUND(AVG(v.valoracion),2) AS "valoracion media"
FROM detalle_venta dv INNER JOIN cafe c
	ON dv.id_cafe = c.id_cafe
INNER JOIN valoraciones v
	ON c.id_cafe =  v.id_cafe
GROUP BY c.nombre_cafe
ORDER BY "valoracion media" DESC
LIMIT 3;""", conn)

estilizar(snobs, zebra=True)
# Out:
# <style type="text/css">
# #T_8e2f6 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_8e2f6 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_8e2f6 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_8e2f6_row0_col0, #T_8e2f6_row0_col1, #T_8e2f6_row0_col2, #T_8e2f6_row2_col0, #T_8e2f6_row2_col1, #T_8e2f6_row2_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_8e2f6_row1_col0, #T_8e2f6_row1_col1, #T_8e2f6_row1_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_8e2f6" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e2f6_level0_col0" class="col_heading level0 col0" >nombre_cafe</th>
#       <th id="T_8e2f6_level0_col1" class="col_heading level0 col1" >formato_paquete</th>
#       <th id="T_8e2f6_level0_col2" class="col_heading level0 col2" >valoracion media</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e2f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e2f6_row0_col0" class="data row0 col0" >Etiopia Yirgacheffe</td>
#       <td id="T_8e2f6_row0_col1" class="data row0 col1" >250g</td>
#       <td id="T_8e2f6_row0_col2" class="data row0 col2" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8e2f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e2f6_row1_col0" class="data row1 col0" >Colombia Huila</td>
#       <td id="T_8e2f6_row1_col1" class="data row1 col1" >250g</td>
#       <td id="T_8e2f6_row1_col2" class="data row1 col2" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8e2f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8e2f6_row2_col0" class="data row2 col0" >Kenia Nyeri</td>
#       <td id="T_8e2f6_row2_col1" class="data row2 col1" >250g</td>
#       <td id="T_8e2f6_row2_col2" class="data row2 col2" >4.710000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ![Imagen Lucia.png](<attachment:Imagen Lucia.png>)

# %% [markdown]
# ### Consulta 6: Top 5 de clientes que mas compran

# %%
top_clientes = pd.read_sql("""SELECT cl.id_cliente,
       cl.nombre_cliente,
       SUM(dv.cantidad * dv.precio_unitario) AS total_gastado
FROM cliente AS cl
JOIN venta AS v ON cl.id_cliente = v.id_cliente
JOIN detalle_venta AS dv ON v.id_venta = dv.id_venta
GROUP BY cl.id_cliente, cl.nombre_cliente
ORDER BY total_gastado DESC
LIMIT 5;""", conn)

estilizar(top_clientes, zebra=True)
# Out:
# <style type="text/css">
# #T_8a951 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_8a951 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_8a951 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_8a951_row0_col0, #T_8a951_row0_col1, #T_8a951_row0_col2, #T_8a951_row2_col0, #T_8a951_row2_col1, #T_8a951_row2_col2, #T_8a951_row4_col0, #T_8a951_row4_col1, #T_8a951_row4_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_8a951_row1_col0, #T_8a951_row1_col1, #T_8a951_row1_col2, #T_8a951_row3_col0, #T_8a951_row3_col1, #T_8a951_row3_col2 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_8a951" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a951_level0_col0" class="col_heading level0 col0" >id_cliente</th>
#       <th id="T_8a951_level0_col1" class="col_heading level0 col1" >nombre_cliente</th>
#       <th id="T_8a951_level0_col2" class="col_heading level0 col2" >total_gastado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a951_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a951_row0_col0" class="data row0 col0" >101</td>
#       <td id="T_8a951_row0_col1" class="data row0 col1" >Aitana Suarez</td>
#       <td id="T_8a951_row0_col2" class="data row0 col2" >552.920000</td>
#     </tr>
#     <tr>
#       <th id="T_8a951_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a951_row1_col0" class="data row1 col0" >103</td>
#       <td id="T_8a951_row1_col1" class="data row1 col1" >Carla Mier</td>
#       <td id="T_8a951_row1_col2" class="data row1 col2" >515.840000</td>
#     </tr>
#     <tr>
#       <th id="T_8a951_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a951_row2_col0" class="data row2 col0" >108</td>
#       <td id="T_8a951_row2_col1" class="data row2 col1" >Hector Solares</td>
#       <td id="T_8a951_row2_col2" class="data row2 col2" >440.490000</td>
#     </tr>
#     <tr>
#       <th id="T_8a951_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8a951_row3_col0" class="data row3 col0" >110</td>
#       <td id="T_8a951_row3_col1" class="data row3 col1" >Jorge Cifuentes</td>
#       <td id="T_8a951_row3_col2" class="data row3 col2" >400.980000</td>
#     </tr>
#     <tr>
#       <th id="T_8a951_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8a951_row4_col0" class="data row4 col0" >105</td>
#       <td id="T_8a951_row4_col1" class="data row4 col1" >Elena Ruiz</td>
#       <td id="T_8a951_row4_col2" class="data row4 col2" >321.460000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Consulta 7: ¿Qué canal tiene más operaciones de venta?

# %%
canal = pd.read_sql("""SELECT 
    cl.nombre_cliente,
    COUNT(DISTINCT CASE WHEN v.canal_venta = 'online' THEN v.id_venta END) AS compras_online,
    COUNT(DISTINCT CASE WHEN v.canal_venta = 'tienda' THEN v.id_venta END) AS compras_tienda,
    CASE 
        WHEN COUNT(DISTINCT CASE WHEN v.canal_venta = 'online' THEN v.id_venta END) = 0 
            THEN 'solo tienda'
        WHEN COUNT(DISTINCT CASE WHEN v.canal_venta = 'tienda' THEN v.id_venta END) = 0 
            THEN 'solo online'
        ELSE 'ambos canales'
    END AS perfil_cliente
FROM cliente cl
JOIN venta v ON cl.id_cliente = v.id_cliente
GROUP BY cl.nombre_cliente
ORDER BY perfil_cliente;""", conn)

estilizar(canal, zebra=True)
# Out:
# <style type="text/css">
# #T_4ced6 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_4ced6 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_4ced6 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_4ced6_row0_col0, #T_4ced6_row0_col1, #T_4ced6_row0_col2, #T_4ced6_row0_col3, #T_4ced6_row2_col0, #T_4ced6_row2_col1, #T_4ced6_row2_col2, #T_4ced6_row2_col3, #T_4ced6_row4_col0, #T_4ced6_row4_col1, #T_4ced6_row4_col2, #T_4ced6_row4_col3, #T_4ced6_row6_col0, #T_4ced6_row6_col1, #T_4ced6_row6_col2, #T_4ced6_row6_col3, #T_4ced6_row8_col0, #T_4ced6_row8_col1, #T_4ced6_row8_col2, #T_4ced6_row8_col3 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_4ced6_row1_col0, #T_4ced6_row1_col1, #T_4ced6_row1_col2, #T_4ced6_row1_col3, #T_4ced6_row3_col0, #T_4ced6_row3_col1, #T_4ced6_row3_col2, #T_4ced6_row3_col3, #T_4ced6_row5_col0, #T_4ced6_row5_col1, #T_4ced6_row5_col2, #T_4ced6_row5_col3, #T_4ced6_row7_col0, #T_4ced6_row7_col1, #T_4ced6_row7_col2, #T_4ced6_row7_col3, #T_4ced6_row9_col0, #T_4ced6_row9_col1, #T_4ced6_row9_col2, #T_4ced6_row9_col3 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_4ced6" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ced6_level0_col0" class="col_heading level0 col0" >nombre_cliente</th>
#       <th id="T_4ced6_level0_col1" class="col_heading level0 col1" >compras_online</th>
#       <th id="T_4ced6_level0_col2" class="col_heading level0 col2" >compras_tienda</th>
#       <th id="T_4ced6_level0_col3" class="col_heading level0 col3" >perfil_cliente</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ced6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ced6_row0_col0" class="data row0 col0" >Aitana Suarez</td>
#       <td id="T_4ced6_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_4ced6_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_4ced6_row0_col3" class="data row0 col3" >ambos canales</td>
#     </tr>
#     <tr>
#       <th id="T_4ced6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4ced6_row1_col0" class="data row1 col0" >Bruno Mendez</td>
#       <td id="T_4ced6_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_4ced6_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_4ced6_row1_col3" class="data row1 col3" >ambos canales</td>
#     </tr>
#     <tr>
#       <th id="T_4ced6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4ced6_row2_col0" class="data row2 col0" >Carla Mier</td>
#       <td id="T_4ced6_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_4ced6_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_4ced6_row2_col3" class="data row2 col3" >ambos canales</td>
#     </tr>
#     <tr>
#       <th id="T_4ced6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4ced6_row3_col0" class="data row3 col0" >Diego Alvarez</td>
#       <td id="T_4ced6_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_4ced6_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_4ced6_row3_col3" class="data row3 col3" >ambos canales</td>
#     </tr>
#     <tr>
#       <th id="T_4ced6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4ced6_row4_col0" class="data row4 col0" >Elena Ruiz</td>
#       <td id="T_4ced6_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_4ced6_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_4ced6_row4_col3" class="data row4 col3" >ambos canales</td>
#     </tr>
#     <tr>
#       <th id="T_4ced6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4ced6_row5_col0" class="data row5 col0" >Fabian Torre</td>
#       <td id="T_4ced6_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_4ced6_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_4ced6_row5_col3" class="data row5 col3" >ambos canales</td>
#     </tr>
#     <tr>
#       <th id="T_4ced6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4ced6_row6_col0" class="data row6 col0" >Gabriela Coto</td>
#       <td id="T_4ced6_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_4ced6_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_4ced6_row6_col3" class="data row6 col3" >ambos canales</td>
#     </tr>
#     <tr>
#       <th id="T_4ced6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4ced6_row7_col0" class="data row7 col0" >Hector Solares</td>
#       <td id="T_4ced6_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_4ced6_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_4ced6_row7_col3" class="data row7 col3" >ambos canales</td>
#     </tr>
#     <tr>
#       <th id="T_4ced6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4ced6_row8_col0" class="data row8 col0" >Iria Pravia</td>
#       <td id="T_4ced6_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_4ced6_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_4ced6_row8_col3" class="data row8 col3" >ambos canales</td>
#     </tr>
#     <tr>
#       <th id="T_4ced6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4ced6_row9_col0" class="data row9 col0" >Jorge Cifuentes</td>
#       <td id="T_4ced6_row9_col1" class="data row9 col1" >7</td>
#       <td id="T_4ced6_row9_col2" class="data row9 col2" >7</td>
#       <td id="T_4ced6_row9_col3" class="data row9 col3" >ambos canales</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np

plt.figure(figsize=(12,6))

x = np.arange(len(canal['nombre_cliente']))   # posiciones en X
width = 0.35                               # ancho de cada barra

plt.bar(x - width/2, canal['compras_online'], width, label='Compras online', color='#6D4C41')
plt.bar(x + width/2, canal['compras_tienda'], width, label='Compras en tienda', color='#A1887F')

plt.xticks(x, canal['nombre_cliente'], rotation=45, ha='right')
plt.ylabel("Número de compras")
plt.title("Comparación de compras por cliente")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Consulta 8: Valoraciones vs proceso_cafe, nivel_tueste

# %%
valoraciones = pd.read_sql("""SELECT 
    c.proceso_cafe, c.nivel_tueste,
    ROUND(AVG(v.valoracion), 2) AS valoracion_media,
    COUNT(v.valoracion) AS total_opiniones
FROM CAFE AS c
INNER JOIN VALORACIONES AS v ON c.id_cafe = v.id_cafe
GROUP BY c.proceso_cafe, c.nivel_tueste
ORDER BY total_opiniones DESC;""", conn)

estilizar(valoraciones, zebra=True)
# Out:
# <style type="text/css">
# #T_dfad9 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_dfad9 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_dfad9 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_dfad9_row0_col0, #T_dfad9_row0_col1, #T_dfad9_row0_col2, #T_dfad9_row0_col3, #T_dfad9_row2_col0, #T_dfad9_row2_col1, #T_dfad9_row2_col2, #T_dfad9_row2_col3 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_dfad9_row1_col0, #T_dfad9_row1_col1, #T_dfad9_row1_col2, #T_dfad9_row1_col3, #T_dfad9_row3_col0, #T_dfad9_row3_col1, #T_dfad9_row3_col2, #T_dfad9_row3_col3 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_dfad9" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfad9_level0_col0" class="col_heading level0 col0" >proceso_cafe</th>
#       <th id="T_dfad9_level0_col1" class="col_heading level0 col1" >nivel_tueste</th>
#       <th id="T_dfad9_level0_col2" class="col_heading level0 col2" >valoracion_media</th>
#       <th id="T_dfad9_level0_col3" class="col_heading level0 col3" >total_opiniones</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfad9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfad9_row0_col0" class="data row0 col0" >Lavado</td>
#       <td id="T_dfad9_row0_col1" class="data row0 col1" >Claro</td>
#       <td id="T_dfad9_row0_col2" class="data row0 col2" >4.810000</td>
#       <td id="T_dfad9_row0_col3" class="data row0 col3" >63</td>
#     </tr>
#     <tr>
#       <th id="T_dfad9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dfad9_row1_col0" class="data row1 col0" >Lavado</td>
#       <td id="T_dfad9_row1_col1" class="data row1 col1" >Medio</td>
#       <td id="T_dfad9_row1_col2" class="data row1 col2" >5.000000</td>
#       <td id="T_dfad9_row1_col3" class="data row1 col3" >28</td>
#     </tr>
#     <tr>
#       <th id="T_dfad9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dfad9_row2_col0" class="data row2 col0" >Honey</td>
#       <td id="T_dfad9_row2_col1" class="data row2 col1" >Medio-Oscuro</td>
#       <td id="T_dfad9_row2_col2" class="data row2 col2" >4.430000</td>
#       <td id="T_dfad9_row2_col3" class="data row2 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_dfad9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dfad9_row3_col0" class="data row3 col0" >Natural</td>
#       <td id="T_dfad9_row3_col1" class="data row3 col1" >Medio</td>
#       <td id="T_dfad9_row3_col2" class="data row3 col2" >3.930000</td>
#       <td id="T_dfad9_row3_col3" class="data row3 col3" >14</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Consulta 9: ¿que formato se vende más?

# %%
formato = pd.read_sql("""SELECT 
    formato_paquete, 
    COUNT(*) AS veces_comprado,
    SUM(cantidad) AS unidades_totales,
    ROUND(SUM("total_venta"), 2) AS facturacion_por_formato
FROM DETALLE_VENTA
GROUP BY formato_paquete
ORDER BY unidades_totales DESC;""", conn)

estilizar(formato, zebra=True)
# Out:
# <style type="text/css">
# #T_e8602 th {
#   background-color: #C8923A;
#   color: #1A0800;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_e8602 td {
#   background-color: #2A1205;
#   color: #F2E0C8;
#   padding: 6px;
# }
# #T_e8602 table {
#   border: 1px solid #C8923A;
#   border-collapse: collapse;
# }
# #T_e8602_row0_col0, #T_e8602_row0_col1, #T_e8602_row0_col2, #T_e8602_row0_col3, #T_e8602_row2_col0, #T_e8602_row2_col1, #T_e8602_row2_col2, #T_e8602_row2_col3 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #2A1205;
#   color: #F2E0C8;
# }
# #T_e8602_row1_col0, #T_e8602_row1_col1, #T_e8602_row1_col2, #T_e8602_row1_col3 {
#   border: 1px solid #C8923A;
#   padding: 6px;
#   background-color: #1E0D02;
#   color: #F2E0C8;
# }
# </style>
# <table id="T_e8602" class="premium-table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8602_level0_col0" class="col_heading level0 col0" >formato_paquete</th>
#       <th id="T_e8602_level0_col1" class="col_heading level0 col1" >veces_comprado</th>
#       <th id="T_e8602_level0_col2" class="col_heading level0 col2" >unidades_totales</th>
#       <th id="T_e8602_level0_col3" class="col_heading level0 col3" >facturacion_por_formato</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8602_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8602_row0_col0" class="data row0 col0" >250g</td>
#       <td id="T_e8602_row0_col1" class="data row0 col1" >44</td>
#       <td id="T_e8602_row0_col2" class="data row0 col2" >84</td>
#       <td id="T_e8602_row0_col3" class="data row0 col3" >1212.620000</td>
#     </tr>
#     <tr>
#       <th id="T_e8602_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8602_row1_col0" class="data row1 col0" >500g</td>
#       <td id="T_e8602_row1_col1" class="data row1 col1" >40</td>
#       <td id="T_e8602_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_e8602_row1_col3" class="data row1 col3" >1127.520000</td>
#     </tr>
#     <tr>
#       <th id="T_e8602_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8602_row2_col0" class="data row2 col0" >1000</td>
#       <td id="T_e8602_row2_col1" class="data row2 col1" >35</td>
#       <td id="T_e8602_row2_col2" class="data row2 col2" >67</td>
#       <td id="T_e8602_row2_col3" class="data row2 col3" >1031.340000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.bar(formato['formato_paquete'], formato['unidades_totales'])
plt.xticks(rotation=45)
plt.title("Ventas por café")
plt.xlabel("Café")
plt.ylabel("Total vendido")
plt.show()
